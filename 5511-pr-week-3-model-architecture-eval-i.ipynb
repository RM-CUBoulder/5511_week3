# %% [markdown]
# # Evaluation Model Framework 2
# #### Code for evaluating three model architectures within Model Framework 2.

# %%
# Import necessary modules
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from os import listdir
import matplotlib.pyplot as plt

# %%
# Function to plot training metrics against the number of epochs
def pd_plot(metric_df,title, path):

    fig, ax = plt.subplots(3, 1, figsize=(8,6))
    ax[0].plot(metric_df.accuracy, linestyle= 'dashed')
    ax[0].plot(metric_df.val_accuracy, linestyle= 'dotted')
    ax[0].legend(["Accuracy", "Val. Accuracy"], loc="lower right")
    ax[0].set_ylabel('Accuracy')
    ax[0].set_ylim(0,1)
    ax[0].set_xticks([0, 4, 8, 12, 16, 20], ['0', '4', '8', '12', '16', '20'])
    
    ax[1].plot(metric_df.auc, linestyle= 'dashed')
    ax[1].plot(metric_df.val_auc, linestyle= 'dotted')
    ax[1].legend(["AUC", "Val. AUC"], loc="lower right")
    ax[1].set_ylabel('AUC')
    ax[1].set_ylim(0,1)
    ax[1].set_xticks([0, 4, 8, 12, 16, 20], ['0', '4', '8', '12', '16', '20'])
    
    ax[2].plot(metric_df.loss, linestyle= 'dashed')
    ax[2].plot(metric_df.val_loss, linestyle= 'dotted')
    ax[2].legend(["Loss", "Val. Loss"], loc="lower right")
    ax[2].set_ylabel('Loss')
    ax[2].set_xticks([0, 4, 8, 12, 16, 20], ['0', '4', '8', '12', '16', '20'])
    ax[2].set_xlabel('# Epoch', fontsize = 12)


    ax[0].set_title(title, fontsize = 16)
    
    fig.tight_layout()
    #plt.show()
    plt.savefig(path)

# %%
# Read Architecture 1 Metrics
output = pd.read_csv('Simple_CNN_Stan.csv')
output
# Out:
#     accuracy       auc      loss  val_accuracy   val_auc   val_loss
# 0   0.524418  0.530463  8.875331      0.397547  0.397547  12.397926
# 1   0.519721  0.528070  1.900904      0.602453  0.543502   3.999741
# 2   0.516893  0.544362  1.204802      0.602453  0.593473   1.438915
# 3   0.516338  0.545779  0.956163      0.602453  0.594887   1.501327
# 4   0.517651  0.544381  0.871332      0.397547  0.423664   3.170102
# 5   0.542902  0.570086  0.769257      0.397547  0.411044   1.802641
# 6   0.547094  0.580897  0.730675      0.397547  0.453697   7.182961
# 7   0.581688  0.617823  0.780262      0.398455  0.446458   0.901014
# 8   0.581082  0.624612  0.673556      0.602453  0.592189   1.815919
# 9   0.593859  0.642349  0.671295      0.602453  0.602316   1.263080
# 10  0.611585  0.664739  0.654362      0.397547  0.419940   1.930924
# 11  0.607899  0.659765  0.657198      0.602453  0.606206   1.109624
# 12  0.641483  0.691009  0.637909      0.602453  0.599467   1.674009
# 13  0.651129  0.695500  0.641449      0.602453  0.598964   1.696128
# 14  0.674663  0.722100  0.628466      0.397547  0.431439   1.689101
# 15  0.685773  0.733895  0.618701      0.602453  0.590401   2.018064
# 16  0.692339  0.739704  0.621451      0.397547  0.448274   3.998523
# 17  0.676935  0.719604  0.655186      0.602453  0.605089   1.511405
# 18  0.698197  0.750423  0.609101      0.397547  0.448028   1.407881
# 19  0.698551  0.747916  0.607211      0.602453  0.597661   1.849803

# %%
# Plot Architecture 1 Metrics
pd_plot(output, 'Simple CNN (Stan.) training metrics', 'simple_cnn_stan.jpeg')

# %%
# Read Architecture 2 Metrics
output1 = pd.read_csv('Basic_CNN_Stan.csv')
output1
# Out:
#     accuracy       auc      loss  val_accuracy   val_auc  val_loss
# 0   0.502954  0.526023  2.790148      0.602453  0.568744  1.324263
# 1   0.576133  0.590801  0.694474      0.602453  0.568394  1.507358
# 2   0.574466  0.593498  0.692543      0.397547  0.433592  2.257185
# 3   0.590526  0.592526  0.695810      0.602453  0.566668  1.113800
# 4   0.591485  0.598306  0.682937      0.602453  0.569040  1.076746
# 5   0.596233  0.600409  0.681507      0.602453  0.568504  1.036346
# 6   0.597091  0.599663  0.680184      0.602453  0.568249  1.096869
# 7   0.599919  0.604120  0.680231      0.397547  0.435060  1.639474
# 8   0.592950  0.597627  0.686293      0.397547  0.434901  1.597639
# 9   0.595475  0.599838  0.684119      0.397547  0.434480  1.459149
# 10  0.594818  0.601332  0.682506      0.397547  0.434548  1.386666
# 11  0.596233  0.603920  0.681457      0.602453  0.571438  0.896864
# 12  0.599717  0.605162  0.676492      0.602453  0.571089  0.887733
# 13  0.599667  0.608122  0.675526      0.397547  0.435086  1.316214
# 14  0.596081  0.602022  0.680433      0.397547  0.434448  1.261536
# 15  0.596334  0.602264  0.679709      0.602453  0.573445  0.878431
# 16  0.599768  0.611254  0.675138      0.397547  0.434400  1.200919
# 17  0.597192  0.610680  0.676726      0.602453  0.577845  0.857177
# 18  0.599717  0.611605  0.674942      0.397547  0.435290  1.155133
# 19  0.594566  0.606231  0.678367      0.397547  0.435210  1.140863

# %%
# Plot Architecture 2 Metrics
pd_plot(output1, 'Basic CNN (Stan.) training metrics', 'basic_cnn_stan.jpeg')

# %%
# Read Architecture 3 Metrics
output2 = pd.read_csv('Basic_CNN_Stan_20per.csv')
output2
# Out:
#     accuracy       auc      loss  val_accuracy   val_auc  val_loss
# 0   0.519772  0.535073  2.749236      0.602453  0.594298  1.787450
# 1   0.567800  0.580332  0.709732      0.397547  0.434752  2.152918
# 2   0.582546  0.592261  0.696708      0.602453  0.564022  1.236186
# 3   0.592344  0.597855  0.687145      0.602453  0.563457  1.137594
# 4   0.592596  0.594955  0.685304      0.602453  0.564553  1.127322
# 5   0.597394  0.600792  0.681985      0.602453  0.564787  1.068975
# 6   0.594515  0.599110  0.682145      0.397547  0.436269  1.618063
# 7   0.595374  0.599326  0.684660      0.602453  0.564976  1.071556
# 8   0.595980  0.601061  0.680443      0.397547  0.439769  1.562626
# 9   0.596384  0.603712  0.683083      0.602453  0.565678  1.034817
# 10  0.599111  0.608440  0.677690      0.397547  0.438872  1.424685
# 11  0.596485  0.603430  0.680590      0.602453  0.566771  0.936371
# 12  0.599970  0.603699  0.678560      0.602453  0.569235  0.974351
# 13  0.599717  0.605468  0.677900      0.397547  0.438254  1.300696
# 14  0.596788  0.604247  0.680150      0.397547  0.438871  1.358514
# 15  0.594919  0.602551  0.681743      0.397547  0.438034  1.281231
# 16  0.595879  0.605665  0.678974      0.397547  0.438737  1.269301
# 17  0.594263  0.608343  0.678901      0.602453  0.578772  0.886400
# 18  0.599667  0.610890  0.675821      0.602453  0.577829  0.953258
# 19  0.599465  0.614431  0.675872      0.602453  0.581718  0.931264

# %%
# Plot Architecture 3 Metrics
pd_plot(output2, 'Basic CNN (Stan. 20%) training metrics', 'basic_cnn_stan_20per.jpeg')
