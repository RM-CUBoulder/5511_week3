# %% [markdown]
# # Evaluation Model Framework 1
# #### Code for evaluating three model architectures within Model Framework 1.

# %%
# Import necessary modules
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from os import listdir
import matplotlib.pyplot as plt

# %%
# Function to plot training metrics against the number of epochs
def pd_plot(metric_df,title, path):

    fig, ax = plt.subplots(3, 1, figsize=(8,6))
    ax[0].plot(metric_df.accuracy, linestyle= 'dashed')
    ax[0].plot(metric_df.val_accuracy, linestyle= 'dotted')
    ax[0].legend(["Accuracy", "Val. Accuracy"], loc="lower right")
    ax[0].set_ylabel('Accuracy')
    ax[0].set_ylim(0,1)
    ax[0].set_xticks([0, 4, 8, 12, 16, 20], ['0', '4', '8', '12', '16', '20'])
    
    ax[1].plot(metric_df.auc, linestyle= 'dashed')
    ax[1].plot(metric_df.val_auc, linestyle= 'dotted')
    ax[1].legend(["AUC", "Val. AUC"], loc="lower right")
    ax[1].set_ylabel('AUC')
    ax[1].set_ylim(0,1)
    ax[1].set_xticks([0, 4, 8, 12, 16, 20], ['0', '4', '8', '12', '16', '20'])
    
    ax[2].plot(metric_df.loss, linestyle= 'dashed')
    ax[2].plot(metric_df.val_loss, linestyle= 'dotted')
    ax[2].legend(["Loss", "Val. Loss"], loc="lower right")
    ax[2].set_ylabel('Loss')
    ax[2].set_xticks([0, 4, 8, 12, 16, 20], ['0', '4', '8', '12', '16', '20'])
    ax[2].set_xlabel('# Epoch', fontsize = 12)

    ax[0].set_title(title, fontsize = 16)
    
    fig.tight_layout()
    plt.savefig(path)

# %%
# Read Architecture 1 Metrics
output = pd.read_csv('Simple_CNN.csv')
output
# Out:
#     accuracy       auc       loss  val_accuracy   val_auc    val_loss
# 0   0.515984  0.519213  26.532612      0.602453  0.602453   41.016365
# 1   0.522953  0.521891  25.784670      0.602453  0.602453   42.590958
# 2   0.523155  0.523769  22.092428      0.602453  0.602453   20.583513
# 3   0.525933  0.528947  20.064478      0.602453  0.602453   47.204380
# 4   0.524569  0.524511  20.616272      0.602453  0.602453   27.577425
# 5   0.525782  0.528600  20.394987      0.397547  0.397547   42.793072
# 6   0.530882  0.532719  19.369314      0.602453  0.602453   28.552139
# 7   0.538710  0.540832  18.400537      0.397547  0.397547   58.787315
# 8   0.523256  0.524442  30.518532      0.602453  0.602453   32.017765
# 9   0.536034  0.539475  23.344458      0.410722  0.412143   17.359217
# 10  0.553810  0.556568  20.679655      0.602453  0.602453   59.416164
# 11  0.544720  0.549922  22.130075      0.600636  0.606627    2.426158
# 12  0.549215  0.551956  21.110823      0.602453  0.602453  132.174698
# 13  0.549467  0.550850  22.949642      0.602453  0.602453   52.996632
# 14  0.552144  0.556943  17.139011      0.397547  0.397547   62.472050
# 15  0.559315  0.561285  16.472061      0.538846  0.626434    2.049500
# 16  0.555628  0.562796  15.281910      0.397547  0.397547   63.814430
# 17  0.553406  0.557564  16.123356      0.600636  0.641316    2.268390
# 18  0.564820  0.571240  13.416469      0.602453  0.602453   38.650291
# 19  0.563002  0.570343  11.758575      0.602453  0.602453    8.985990

# %%
# Plot Architecture 1 Metrics
pd_plot(output, 'Simple_CNN training metrics','simple_cnn.jpeg')

# %%
# Read Architecture 2 Metrics
output1 = pd.read_csv('Basic_CNN.csv')
output1
# Out:
#     accuracy       auc      loss  val_accuracy   val_auc  val_loss
# 0   0.522903  0.537365  2.418547      0.397547  0.397366  2.382312
# 1   0.551285  0.575359  0.714407      0.602453  0.603898  1.224959
# 2   0.586890  0.598062  0.687219      0.397547  0.388072  2.089719
# 3   0.585778  0.591295  0.695997      0.602453  0.658151  1.220074
# 4   0.593152  0.602870  0.684799      0.397547  0.356619  1.877133
# 5   0.592344  0.598123  0.687036      0.602453  0.662376  1.097071
# 6   0.599616  0.601541  0.680755      0.602453  0.664198  1.096807
# 7   0.596889  0.600806  0.681332      0.602453  0.657897  1.065437
# 8   0.599465  0.605328  0.679700      0.602453  0.667640  1.050527
# 9   0.597697  0.617880  0.674912      0.602453  0.726846  1.129296
# 10  0.597142  0.617379  0.676152      0.602453  0.642548  1.034434
# 11  0.598606  0.625205  0.671813      0.602453  0.636204  1.068976
# 12  0.600727  0.638695  0.666117      0.397547  0.467106  1.505963
# 13  0.598253  0.634216  0.671047      0.602453  0.629030  1.200395
# 14  0.583203  0.627380  0.677128      0.602453  0.631285  1.237092
# 15  0.587799  0.634746  0.672060      0.602453  0.647281  1.448320
# 16  0.602343  0.647312  0.674954      0.602453  0.675223  1.394450
# 17  0.648907  0.695403  0.642061      0.602453  0.677783  1.718548
# 18  0.589768  0.662883  0.647216      0.602453  0.646034  1.160233
# 19  0.575021  0.625694  0.693546      0.602453  0.602453  2.411898

# %%
# Plot Architecture 2 Metrics
pd_plot(output1, 'Basic_CNN training metrics','basic_cnn.jpeg')

# %%
# Read Architecture 3 Metrics
output2 = pd.read_csv('Basic_CNN_20perc.csv')
output2
# Out:
#     accuracy       auc      loss  val_accuracy   val_auc  val_loss
# 0   0.538003  0.549295  1.862444      0.397547  0.338974  2.781864
# 1   0.580425  0.590821  0.706368      0.602453  0.606876  1.265699
# 2   0.590576  0.601318  0.684753      0.602453  0.630244  1.166794
# 3   0.599010  0.601818  0.682484      0.602453  0.670690  1.152603
# 4   0.593808  0.604799  0.680995      0.602453  0.655834  1.080333
# 5   0.599566  0.612951  0.676514      0.602453  0.646435  1.168056
# 6   0.598101  0.631015  0.673163      0.397547  0.372517  1.633631
# 7   0.596536  0.633414  0.672364      0.602453  0.621531  1.096624
# 8   0.592899  0.645974  0.661120      0.602453  0.631006  1.205126
# 9   0.593606  0.649369  0.655669      0.397547  0.482676  1.813294
# 10  0.598808  0.654749  0.657812      0.397547  0.401692  2.212125
# 11  0.580021  0.646819  0.658538      0.397547  0.390879  2.449054
# 12  0.611989  0.667679  0.662048      0.602453  0.636925  1.415325
# 13  0.578860  0.651072  0.648771      0.602453  0.640987  1.220252
# 14  0.598354  0.664594  0.645528      0.397547  0.456886  1.672483
# 15  0.578809  0.647749  0.648871      0.602453  0.641510  1.343578
# 16  0.581334  0.651895  0.645489      0.602453  0.627778  1.488279
# 17  0.584516  0.658499  0.639252      0.602453  0.647411  1.272524
# 18  0.580829  0.654108  0.640721      0.602453  0.642022  0.882002
# 19  0.577042  0.653262  0.633682      0.602453  0.643364  0.837367

# %%
# Plot Architecture 3 Metrics
pd_plot(output2, 'Basic_CNN training metrics (20%)','basic_cnn_20perc.jpeg')
